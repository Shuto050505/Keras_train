# %%
import tensorflow as tf
import keras
import numpy as np

# %%
from keras.datasets import mnist
from keras.models import Sequential
from keras.models import Model
from keras.layers import Dense, Flatten, Dropout, Input
from keras.layers import Convolution2D, MaxPooling2D, BatchNormalization
from keras.optimizers import Adam
from keras.callbacks import EarlyStopping
from keras import backend as K

# %%
from pandas import Series
batch_size = 100
nb_classes = 10
nb_epoch = 10
img_channels, img_rows, img_cols = 1, 28, 28
FILT = Series({'N':3,'num1':32,'num2':64,'num3':1024})

# %%
# load MNIST data
(X_train, y_train), (X_test, y_test) = mnist.load_data()

X_train = X_train.reshape(60000,1,28,28).astype('float32')
X_test = X_test.reshape(10000,1,28,28).astype('float32')
X_train /= 255.0
X_test /= 255.0

# convert class vectors to 1-of-K format
#[2] -> [0,0,1,0, ... ,0]
y_train = np_utils.to_categorical(y_train, nb_classes)
y_test = np_utils.to_categorical(y_test, nb_classes)

print('train samples: ', X_train.shape)
print('test samples: ', X_test.shape)
# Out:
# train samples:  (60000, 1, 28, 28)
# test samples:  (10000, 1, 28, 28)

# %%
def m6_1():
    input_shape = (img_channels,img_rows, img_cols)
    
    model.add(Convolution2D(FILT.num1,FILT.N,FILT.N, init='uniform', border_mode='same',activation='relu',input_shape=input_shape))
    model.add(Convolution2D(FILT.num1, FILT.N, FILT.N, init='uniform', border_mode='same',activation='relu'))
    model.add(MaxPooling2D(pool_size=(2, 2), border_mode='same'))
    model.add(Dropout(0.25))

    model.add(Convolution2D(FILT.num2, FILT.N, FILT.N, init='uniform', border_mode='same',activation='relu'))
    model.add(Convolution2D(FILT.num2, FILT.N, FILT.N, init='uniform', border_mode='same',activation='relu'))
    model.add(MaxPooling2D(pool_size=(2, 2), border_mode='same'))
    model.add(Dropout(0.25))

    model.add(Flatten())
    model.add(Dense(FILT.num3, init='uniform',activation='relu'))
    model.add(Dropout(0.5))
    model.add(Dense(nb_classes, activation='softmax'))

# %%
# building the model
model = Sequential()
m6_1()

model.compile(loss='categorical_crossentropy',optimizer='adam',metrics=['accuracy'])
early_stopping = EarlyStopping(monitor = 'val_loss', patience = 2)
# Out:
# building the model ...

# %%
model.fit(X_train, y_train, nb_epoch = 5, batch_size = 100, callbacks = [early_stopping])
score = model.evaluate(X_test, y_test)
# Out:
# Epoch 1/5
#  - ETA: 0s - loss: 0.4410 - acc: 0.8540
# C:\Users\shuto05\Anaconda3\lib\site-packages\keras\callbacks.py:448: RuntimeWarning: Early stopping requires val_loss available!
#   (self.monitor), RuntimeWarning)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-33-e45a249fa698> in <module>()
# ----> 1 model.fit(X_train, y_train, nb_epoch = 5, batch_size = 100, callbacks = [early_stopping])
#       2 score = model.evaluate(X_test, y_test)
#
# C:\Users\shuto05\Anaconda3\lib\site-packages\keras\models.py in fit(self, x, y, batch_size, nb_epoch, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, **kwargs)
#     670                               class_weight=class_weight,
#     671                               sample_weight=sample_weight,
# ...

# %%
# training
#adam = Adam(lr=0.001, beta_1=0.9, beta_2=0.999, epsilon=1e-08)

hist = model.fit(X_train, Y_train,
              batch_size=batch_size,
              nb_epoch=nb_epoch,
              validation_split=0.1,
              verbose=1)
# Out:
# Train on 54000 samples, validate on 6000 samples
# Epoch 1/100

# %%
model.compile(loss='categorical_crossentropy',optimizer=Adam(),metrics=['accuracy'])

 # early stopping
early_stopping = EarlyStopping(monitor='val_loss', patience=2)
          
# training
hist = model.fit(X_train, y_train,
                 batch_size=batch_size,verbose=1,
                 nb_epoch=nb_epoch,validation_split=0.1,
                 callbacks=[early_stopping])

# evaluate
score = model.evaluate(X_test, y_test, verbose=1)
print('Test loss:', score[0])
print('Test accuracy:', score[1])
          
# plot loss
loss = hist.history['loss']
val_loss = hist.history['val_loss']
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-50-5de5b533104f> in <module>()
#       2 hist = model.fit(X_train, y_train,
#       3                  batch_size=batch_size,
# ----> 4                  nb_epoch=nb_epoch)
#
# C:\Users\shuto05\Anaconda3\lib\site-packages\keras\models.py in fit(self, x, y, batch_size, nb_epoch, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, **kwargs)
#     648         """
#     649         if self.model is None:
# --> 650             raise RuntimeError('The model needs to be compiled '
#     651                                'before being used.')
#     652         if 'show_accuracy' in kwargs:
#
# RuntimeError: The model needs to be compiled before being used.

# %%
# evaluate
score = model.evaluate(X_test, y_test, verbose=1)
print('Test loss:', score[0])
print('Test accuracy:', score[1])
          
# plot loss
loss = hist.history['loss']
val_loss = hist.history['val_loss']
